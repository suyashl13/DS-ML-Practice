# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.linspace(0,6,9)
y = np.linspace(0,7,9)
x
# Out:
# array([0.  , 0.75, 1.5 , 2.25, 3.  , 3.75, 4.5 , 5.25, 6.  ])

# %%
plt.plot(x, y)
