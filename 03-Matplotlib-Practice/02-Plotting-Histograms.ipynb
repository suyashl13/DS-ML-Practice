# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Bar Chart Example
# <hr>

# %%
plt.bar([1,2,3,4,5],[2,4,6,8,10], label='Movies')
plt.xlabel('X AXIS')
plt.ylabel('Y AXIS')
plt.title('Random Label')
# Out:
# Text(0.5, 1.0, 'Random Label')

# %%
x = np.random.randn(5,5)
plt.hist(x)
# Out:
# (array([[0., 0., 0., 2., 2., 1., 0., 0., 0., 0.],
#         [0., 2., 0., 0., 2., 0., 1., 0., 0., 0.],
#         [0., 0., 0., 3., 0., 0., 0., 1., 0., 1.],
#         [1., 0., 1., 1., 2., 0., 0., 0., 0., 0.],
#         [1., 0., 0., 0., 2., 1., 0., 1., 0., 0.]]),
#  array([-2.3434866 , -1.83575515, -1.3280237 , -0.82029224, -0.31256079,
#          0.19517066,  0.70290212,  1.21063357,  1.71836502,  2.22609648,
#          2.73382793]),
#  <a list of 5 BarContainer objects>)
